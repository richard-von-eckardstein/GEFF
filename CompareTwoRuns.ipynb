# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from importlib import reload
import GEFSchwinger
reload(GEFSchwinger)
from GEFSchwinger import GEF
#from GEF import GEF as GEF2
from utilities import PlotComp#, EndOfInflation2
from scipy.interpolate import CubicSpline, RectBivariateSpline
from scipy.integrate import quad
from scipy.optimize import fsolve
import os

# %%
it = "_0it"
SE = "mix"

# %%
alpha = 0.
Mpl = 1.
beta = 25.
MR = 6e-6*Mpl
phi0 = 15.55*Mpl
dphidt0 = -np.sqrt(2/3)*MR*Mpl
ini = {"phi":phi0, "dphi":dphidt0, "delta":1.0, "rhoChi":0.0}
ntr = 55
#G = GEF(alpha, beta, Mpl, ini, M, ntr, SE, AltDamp=0, approx=True)
#F = GEF(alpha, beta, Mpl, ini, M, ntr, SE, AltDamp=1, approx=True)
H = GEF(alpha, beta, Mpl, ini, MR, ntr, SE, AltDamp=0, approx=True)
omegaR=H.H0
file = "Out/GEF_Beta25.0_SE"+str(SE)+ "_KDep_Final" + it + ".dat"
H.LoadData(file)
H.Unitful()

tR = H.vals["t"]
NR = H.vals["N"]
xiR = H.vals["xi"]
xieffR = H.vals["xieff"]
phiR = H.vals["phi"]
dphiR = H.vals["dphi"]
deltaR = H.vals["delta"]
HR = H.vals["H"]
rhoChiR = H.vals["rhoChi"]
ER = H.vals["E"]
BR = H.vals["B"]
GR = abs(H.vals["G"])
rhoChiR = H.vals["rhoChi"]
sER = H.vals["sigmaE"]
sBR = H.vals["sigmaB"]
khR = H.vals["kh"]
kSR = khR#H.vals["kS"]
aR = H.vals["a"]
VR = H.potential()
#khOR = data["khO"]*omega
#khER = data["khE"]*omega
#khLR = data["khL"]*omega

# %%
alpha = 0.
Mpl = 1.
beta = 25.
MS = 6e-6*Mpl
phi0 = 15.55*Mpl
dphidt0 = -np.sqrt(2/3)*MS*Mpl
ini = {"phi":phi0, "dphi":dphidt0, "delta":1.0, "rhoChi":0.0}
ntr = 55
#G = GEF(alpha, beta, Mpl, ini, M, ntr, SE, AltDamp=0, approx=True)
#F = GEF(alpha, beta, Mpl, ini, M, ntr, SE, AltDamp=1, approx=True)
H = GEF(alpha, beta, Mpl, ini, MS, ntr, SE, AltDamp=0, approx=True)
omegaS=H.H0
file = "Out/GEF_Beta25.0_SE"+str(SE)+"_KDep_New" + it + ".dat"
H.LoadData(file)
H.Unitful()

tS = H.vals["t"]
NS = H.vals["N"]
xiS = H.vals["xi"]
xieffS = H.vals["xieff"]

phiS = H.vals["phi"]
dphiS = H.vals["dphi"]
deltaS = H.vals["delta"]
HS = H.vals["H"]
rhoChiS = H.vals["rhoChi"]
ES = H.vals["E"]
BS = H.vals["B"]
GS = abs(H.vals["G"])
rhoChiS = H.vals["rhoChi"]
sES = H.vals["sigmaE"]
sBS = H.vals["sigmaB"]
khS = H.vals["kh"]
kSS = khS#H.vals["kS"]
aS = H.vals["a"]
VS = H.potential()
#khOS = data["khO"]*omega
#khES = data["khE"]*omega

# %%
plt.plot(NS, xiS, "r", label=r"$M = 6 \times 10^{-5} \ M_P$")
#plt.plot(NS, xieffS, "m:")
plt.plot(NR, xiR, "b", label=r"$M = 6 \times 10^{-6} \ M_P$")
#plt.plot(NR, xieffR, "c:")
plt.plot(NR, np.ones(NR.size)*(-3), "k:")
plt.ylabel(r"$\xi$")
plt.xlabel(r"$N$")
plt.legend(loc=0)

# %%
#MS = 6e-5
#MR = 6e-6
#rhoMS = 3*MS**2
#rhoMR = 3*MR**2
plt.plot(tS*MS, 0.5*ES/MS**4, "r", label=r"$M = 6 \times 10^{-5} \ M_P$")
plt.plot(tR*MR, 0.5*ER/MR**4, "b", label=r"$M = 6 \times 10^{-6} \ M_P$")
plt.xlim(15, 19)
plt.yscale("log")
plt.ylim(1e6, 2e7)
plt.xlabel(r"$t M$")
plt.ylabel(r"$\rho \ / \ M^4$")
#plt.ylim(1e2,1e4)
plt.legend(loc=0)
plt.show()

# %%
plt.plot(NS, CubicSpline(NR, ER)(NS)/ES*(MS/MR)**4)

# %%
fig, ax = plt.subplots(8,2, figsize=(10,10), sharex=True)

ax[0,0].plot(NS, ES, "b")
PlotComp(ax[0,0], ax[1,0], NR, ER, NS, ES, col="k:")
ax[0,0].set_yscale("log")
ax[0,1].plot(NS, BS, "b")
PlotComp(ax[0,1], ax[1,1], NR, BR, NS, BS, col="k:")
ax[0,1].set_yscale("log")

ax[2,0].plot(NS, GS, "b")
PlotComp(ax[2,0], ax[3,0], NR, GR, NS, GS, col="k:")
ax[2,0].set_yscale("log")
ax[2,1].plot(NS, dphiS, "b")
PlotComp(ax[2,1], ax[3,1], NR, dphiR, NS, dphiS, col="k:")

ax[4,0].plot(NS, khS, "b")
PlotComp(ax[4,0], ax[5,0], NR, khR, NS, khS, col="k:")
ax[4,0].plot(NS, 1/HS, "g")
PlotComp(ax[4,0], ax[5,0], NR, 1/HR, NS, 1/HS, col="c:")
ax[4,0].set_yscale("log")
ax[4,0].plot(NS, kSS, "r")
PlotComp(ax[4,0], ax[5,0], NR, kSR, NS, kSS, col="m:")
ax[4,0].set_yscale("log")

ax[4,1].plot(NS, rhoChiS, "b")
PlotComp(ax[4,1], ax[5,1], NR, rhoChiR, rhoChiS, rhoChiS, col="k:")
ax[4,1].set_yscale("log")

ax[6,0].plot(NS, phiS, "b")
PlotComp(ax[6,0], ax[7,0], NR, phiR, NS, phiS, col="k:")
ax[6,1].plot(NS, sES, "b")
PlotComp(ax[6,1], ax[7,1], NR, sER, NS, sES, col="k:")
ax[6,1].plot(NS, sBS, "r")
PlotComp(ax[6,1], ax[7,1], NR, sBR, NS, sBS, col="m:")
ax[6,1].set_yscale("log")

lines_labels = [ax[0,0].get_legend_handles_labels()]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels)

"""ax[0,0].set_ylim(-0.5,10)
ax[2,0].set_ylim(-4.5e-6,1e-6)
ax[4,0].set_ylim(-20,20)
ax[4,0].set_ylim(1e7, 2e18)"""

ax[0,0].set_ylim(1e-17, 5e-10)#2.5e-18, 1e-13)
ax[0,1].set_ylim(1e-17, 5e-10)#2.5e-18, 1e-13)
ax[2,0].set_ylim(1e-17, 5e-10)#2.5e-18, 1e-13)
#ax[2,1].set_ylim(1e-17, 2.5e-13)
ax[4,0].set_ylim(1e15,1e24)#1e-5, 1e24)
ax[4,1].set_ylim(1e-18, 1e-13)#2.5e-18, 1e-13)
ax[6,1].set_ylim(1e-6, 1e-3)#2.5e-18, 1e-13)


for i in range(4):
    for j in range(2):
        ax[2*i+1,j].set_ylim(1e-8, 1e0)
        ax[2*i+1,j].set_yticks(10**(-1.*np.arange(0, 8, 2)))

for ax in fig.axes:
    ax.grid(True)
    ax.set_xlim(45, max([*NS, *NR]))
    #ax.set_xlim(45, 61)
plt.show()

# %%
fig, ax = plt.subplots(8,2, figsize=(10,10), sharex=True)

ax[0,0].plot(NS, ES, "b")
PlotComp(ax[0,0], ax[1,0], NR, ER, NS, ES, col="k:")
ax[0,0].set_yscale("log")
ax[0,1].plot(NS, BS, "b")
PlotComp(ax[0,1], ax[1,1], NR, BR, NS, BS, col="k:")
ax[0,1].set_yscale("log")

ax[2,0].plot(NS, GS, "b")
PlotComp(ax[2,0], ax[3,0], NR, GR, NS, GS, col="k:")
ax[2,0].set_yscale("log")
ax[2,1].plot(NS, dphiS, "b")
PlotComp(ax[2,1], ax[3,1], NR, dphiR, NS, dphiS, col="k:")

ax[4,0].plot(NS, khS, "b")
PlotComp(ax[4,0], ax[5,0], NR, khR, NS, khS, col="k:")
ax[4,0].plot(NS, (aS*HS), "g")
PlotComp(ax[4,0], ax[5,0], NR, (aR*HR), NS, (aS*HS), col="c:")
ax[4,0].set_yscale("log")
ax[4,0].plot(NS, kSS, "r")
PlotComp(ax[4,0], ax[5,0], NR, kSR, NS, kSS, col="m:")
ax[4,0].set_yscale("log")

ax[4,1].plot(NS, rhoChiS, "b")
PlotComp(ax[4,1], ax[5,1], NR, rhoChiR, rhoChiS, rhoChiS, col="k:")
ax[4,1].set_yscale("log")

ax[6,0].plot(NS, phiS, "b")
PlotComp(ax[6,0], ax[7,0], NR, phiR, NS, phiS, col="k:")
ax[6,1].plot(NS, sES, "b")
PlotComp(ax[6,1], ax[7,1], NR, sER, NS, sES, col="k:")
ax[6,1].plot(NS, sBS, "r")
PlotComp(ax[6,1], ax[7,1], NR, sBR, NS, sBS, col="m:")
ax[6,1].set_yscale("log")

lines_labels = [ax[0,0].get_legend_handles_labels()]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels)

"""ax[0,0].set_ylim(-0.5,10)
ax[2,0].set_ylim(-4.5e-6,1e-6)
ax[4,0].set_ylim(-20,20)
ax[4,0].set_ylim(1e7, 2e18)"""

ax[0,0].set_ylim(1e-20, 5e-14)#2.5e-18, 1e-13)
ax[0,1].set_ylim(1e-20, 5e-14)#2.5e-18, 1e-13)
ax[2,0].set_ylim(1e-20, 5e-14)#2.5e-18, 1e-13)
#ax[2,1].set_ylim(1e-17, 2.5e-13)
ax[4,0].set_ylim(1e-4,1e24)#1e-5, 1e24)
ax[4,1].set_ylim(1e-24, 1e-13)#2.5e-18, 1e-13)
ax[6,1].set_ylim(1e-7, 1e-3)#2.5e-18, 1e-13)


for i in range(4):
    for j in range(2):
        ax[2*i+1,j].set_ylim(1e-8, 1e0)
        ax[2*i+1,j].set_yticks(10**(-1.*np.arange(0, 8, 2)))

for ax in fig.axes:
    ax.grid(True)
    ax.set_xlim(0, max([*NS, *NR]))
    #ax.set_xlim(1, 61)
plt.show()
# Out:
# /home/richard/Documents/Phd Muenster/Axions in the early Universe/GEF/utilities.py:14: RuntimeWarning: invalid value encountered in divide
#   ax2.plot(Nref, abs(spl/Yref-1), col)

# %%
plt.plot(kSR/khR, xiR)
#plt.plot(kSS/khS, xiS)
plt.xlim(0, 1)
plt.ylim(-4.5, -1.5)
# Out:
# (-4.5, -1.5)

# %%
N1 = EndOfInflation2(NR, dphiR, VR, ER, BR, rhoChiR, omega, tol=1e-4)
N2 = EndOfInflation2(NS, dphiS, VS, ES, BS, rhoChiS, omega, tol=1e-4)
print(max(NS), max(NR))
# Out:
# 61.016099563218475
# 61.016101002759264
# 61.33884967534674 61.33884862063283

# %%
#plt.plot(NS, rhoChiS/(3*HS**2))
plt.plot(NR, rhoChiR/(3*HR**2))
#plt.plot(NS, kSS/(aS*HS))
plt.plot(NR, kSR/(aR*HR))
#plt.xlim(0,30)
#plt.ylim(-1e-3, 1e-1)
plt.yscale("log")

# %%
plt.plot(NR, kSR)
plt.plot(NR, khR)
plt.xlim(50, 61)
plt.ylim(1e18, 1e23)
plt.yscale("log")

# %%
#plt.plot(NR, khLR, "y:")
#plt.plot(NR, khER, "m:")
#plt.plot(NR, khOR, "c:")
plt.plot(NR, khR, "g", label="khR")
plt.plot(NS, khS, "k", label="khS")
plt.plot(NS, kSS, "r", label="kSS")
plt.plot(NR, kSR, "b", label="kSS")
#plt.plot(NS, kSS, "r")
plt.yscale("log")
plt.legend(loc=0)
plt.ylim(1e15, 1e24)
plt.xlim(45, 61)
# Out:
# (45.0, 61.0)

# %%
#plt.plot(NR, khLR, "y:")
#plt.plot(NR, khER, "m:")
#plt.plot(NR, khOR, "c:")
plt.plot(NR, khR, "g", label="khR")
plt.plot(NS, khS, "k", label="khS")
plt.plot(NS, kSS, "r:", label="kSS")
plt.plot(NR, kSR, "b:", label="kSR")
#plt.plot(NS, kSS, "r")
plt.yscale("log")
plt.legend(loc=0)
plt.ylim(4e17, 1e20)
plt.xlim(49.5, 55.)
# Out:
# (49.5, 55.0)

# %%
plt.plot(NS, np.log(khS/aS), "m:")
plt.plot(NR, np.log(khR/aR), "r:")
plt.plot(NS, np.log(kSS/aS), "c:")
plt.plot(NR, np.log(kSR/aR), "b:")
plt.plot(NS, np.log(HS), "y:")
plt.plot(NR, np.log(HR), "g:")
plt.xlim(0, 20)
plt.ylim(-11,-8)

# %%
plt.plot(NS, np.log(khS/aS), "m:")
plt.plot(NR, np.log(khR/aR), "r:")
plt.plot(NS, np.log(kSS/aS), "c:")
plt.plot(NR, np.log(kSR/aR), "b:")
plt.show()

# %%
plt.plot(NR, np.log(khR/khER), "m:")
plt.plot(NR, np.log(khR/khOR), "c:")
plt.plot(NS, np.log(khS/khES), "r:")
plt.plot(NS, np.log(khS/khOS), "b:")
plt.plot(NR, np.zeros(NR.size), "k:")
plt.ylim(-5e-1, 5e-1)

# %%
print(CubicSpline(NS, tS)(42))

# %%
plt.plot(NR, np.log(kSR/khR), "m:")
plt.plot(NS, np.log(kSS/khS), "c:")
plt.plot(NS, np.zeros(NS.shape), "k:")
plt.plot(NS, -0.5e-3*np.ones(NS.shape), "r:")
plt.yscale("symlog")
plt.ylim(-1e-3, 1e-3)
#plt.yticks(np.array([-1e0, -1e-3, -1e-6, 0, 1e0, 1e-3, 1e-6]))
plt.grid(True)
plt.xlim(0, 62)

# %%
plt.plot(NR, np.log(BR/CubicSpline(NS, BS)(NR)), "m:")
"""plt.plot(NS, np.log(kSS/khS), "c:")
plt.plot(NS, np.zeros(NS.shape), "k:")
plt.plot(NS, -0.5e-3*np.ones(NS.shape), "r:")

plt.ylim(-1e-3, 1e-3)"""
#plt.yticks(np.array([-1e0, -1e-3, -1e-6, 0, 1e0, 1e-3, 1e-6]))
plt.yscale("symlog")
plt.grid(True)
plt.xlim(0, 62)

# %%
xi = H.vals["xi"]
xieff = H.vals["xieff"]
plt.plot(N, xi, "r")
plt.plot(N, xieff, "g:")
plt.xlim(46, 62)
plt.ylim(-22.5, 0.0)
plt.show()

# %%
plt.plot(N, H.vals["sigmaE"]/(2*H.vals["H"]))
plt.plot(N, H.vals["sigmaEk"]/(2*H.vals["H"]))
plt.xlim(46, 62)
plt.yscale("log")

# %%
E = H.vals["E"]
G = abs(H.vals["G"])
B = H.vals["B"]
plt.plot(N, E, "b")
plt.plot(N, B, "r")
plt.plot(N, G, "g")
plt.yscale("log")
plt.xlim(46, 62)
plt.ylim(1e0, 1e5)
plt.show()

# %%
H.CreateDeltaFunction()

# %%
plt.plot(N, H.vals["delta"], "g")
plt.plot(N, H.deltaf(H.vals["t"]), "r")
plt.xlim(46, 62)
plt.show()

# %%
tferm = H.vals["tferm"]

plt.plot(t, H.Bmf(t), "b-")
plt.plot(t, H.Bmf2(t), "b:")
plt.plot(t, np.log(ks/kh), "c:")
plt.plot(t, np.zeros(t.shape), "k:")
plt.plot(t, t-tferm, "m:")
#plt.yscale("log")
plt.ylim(-2,25)

# %%
sol = H.IterateGEF(t1=114.)

# %%
print(sol)

# %%
#H.Unitful()
omega=H.H0

file = "Out/GEF_Beta25.0_SE-1.0_KDep_5it.dat"
input_df = pd.read_table(file, sep=",")
data = dict(zip(input_df.columns[1:],input_df.values[1:,1:].T))

N4 = data["N"]
xi4 = data["xi"]
xieff4 = data["xieff"]
dphi4 = data["dphi"]*omega
delta4 = data["delta"]
H4 = data["H"]*omega
rhoChi4 = data["rhoChi"]*omega**4
E4 = data["E"]*omega**4
B4 = data["B"]*omega**4
G4 = data["G"]*omega**4
sE4 = data["sigmaE"]*omega
s4 = data["s"]
kh4 = data["kh"]*omega

t2 = H.vals["t"]
N2 = H.vals["N"]
xi2 = H.vals["xi"]
xieff2 = H.vals["xieff"]
dphi2 = H.vals["dphi"]
H2 = H.vals["H"]
delta2 = H.vals["delta"]
rhoChi2 = H.vals["rhoChi"]
E2= H.vals["E"]
B2 = H.vals["B"]
G2 = H.vals["G"]
sE2 = H.vals["sigmaE"]
s2 = H.vals["s"]
kh2 = H.vals["kh"]
khE = H.vals["khE"]
khO = H.vals["khO"]
kS = H.vals["kS"]

# %%
H.IterateGEF(t1=114.)

# %%
H.Unitful()

t1 = H.vals["t"]
N1 = H.vals["N"]
xi1 = H.vals["xi"]
xieff1 = H.vals["xieff"]
dphi1 = H.vals["dphi"]
H1 = H.vals["H"]
delta1 = H.vals["delta"]
rhoChi1 = H.vals["rhoChi"]
E1= H.vals["E"]
B1 = H.vals["B"]
G1 = H.vals["G"]
sE1 = H.vals["sigmaE"]
s1 = H.vals["s"]
kh1 = H.vals["kh"]

# %%
fig, ax = plt.subplots(5,2, figsize=(10,10), sharex=True)

ax[0,0].plot(N4, xi4, "b:", label="Old Delta")
ax[0,0].plot(N1, xi1, "r:", label="K-Dependant Delta 2 It")
ax[0,0].plot(N2, xi2, "g-", label="K-Dependant Delta 1 It")
ax[0,0].plot(N3, xi3, "c:", label="K-Dependant Delta")
ax[0,0].set_ylabel(r"$\xi$")


ax[0,1].plot(N4, dphi4, "b:")
ax[0,1].plot(N1, dphi1, "r:")
ax[0,1].plot(N2, dphi2*omega, "g-")
ax[0,1].plot(N3, dphi3, "c:")
ax[0,1].set_ylabel(r"$\dot{\phi}$")
#ax[0,1].set_ylabel(r"$\xi_{eff}$")

ax[1,0].plot(N4, delta4, "b:")
ax[1,0].plot(N1, delta1, "r:")
ax[1,0].plot(N2, delta2, "g-")
ax[1,0].plot(N3, delta3, "c:")
ax[1,0].set_ylabel(r"$\Delta$")

ax[1,1].plot(N4, H4, "b:")
ax[1,1].plot(N1, H1, "r:")
ax[1,1].plot(N2, H2*omega, "g-")
ax[1,1].plot(N3, H3, "c:")
ax[1,1].set_ylabel(r"$H$")

ax[2,0].plot(N4, E4, "b:")
ax[2,0].plot(N1, E1, "r:")
ax[2,0].plot(N2, E2*omega**4, "g-")
ax[2,0].plot(N3, E3, "c:")
ax[2,0].set_ylabel(r"$E$")
ax[2,0].set_yscale("log")

ax[2,1].plot(N4, B4, "b:")
ax[2,1].plot(N1, B1, "r:")
ax[2,1].plot(N2, B2*omega**4, "g-")
ax[2,1].plot(N3, B3, "c:")
ax[2,1].set_ylabel(r"$B$")
ax[2,1].set_yscale("log")

ax[3,0].plot(N4, rhoChi4, "b:")
ax[3,0].plot(N1, rhoChi1, "r:")
ax[3,0].plot(N2, rhoChi2*omega**4, "g-")
ax[3,0].plot(N3, rhoChi3, "c:")
ax[3,0].set_ylabel(r"$\rho_\chi$")
ax[3,0].set_yscale("log")

ax[3,1].plot(N4, abs(G4), "b:")
ax[3,1].plot(N1, abs(G1), "r:")
ax[3,1].plot(N2, abs(G2)*omega**4, "g-")
ax[3,1].plot(N3, abs(G3), "c:")
ax[3,1].set_ylabel(r"$G$")
ax[3,1].set_yscale("log")

ax[4,0].plot(N4, sE4, "b:")
ax[4,0].plot(N1, sE1, "r:")
ax[4,0].plot(N2, sE2*omega, "g-")
#ax[4,0].plot(N2, sEk, "g-")
#ax[4,0].plot(N3, sEk3, "c:")
ax[4,0].plot(N3, sE3, "c:")
ax[4,0].set_ylabel(r"$\sigma_E$")
ax[4,0].set_yscale("log")

ax[4,1].plot(N4, s4, "b:")
ax[4,1].plot(N1, s1, "r:")
ax[4,1].plot(N2, s2, "g-")
#ax[4,1].plot(N2, sk, "g-")
#ax[4,1].plot(N3, sk3, "c:")
ax[4,1].plot(N3, s3, "c:")
ax[4,1].set_ylabel(r"$s$")
#ax[4,1].set_yscale("log")

lines_labels = [ax[0,0].get_legend_handles_labels()]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels)

"""ax[0,0].set_ylim(-0.5,10)
ax[2,0].set_ylim(-4.5e-6,1e-6)
ax[4,0].set_ylim(-20,20)
ax[4,0].set_ylim(1e7, 2e18)"""

#ax[0,1].set_ylim(1e13, 1e23)
ax[2,0].set_ylim(1e-17, 2.5e-13)
ax[2,1].set_ylim(1e-17, 2.5e-13)
ax[3,0].set_ylim(1e-17, 2.5e-13)
ax[3,1].set_ylim(1e-17, 2.5e-13)
ax[4,0].set_ylim(5e-7, 1e-3)
#ax[4,1].set_ylim(1e-6, 8e-3)

for ax in fig.axes:
    ax.grid(True)
    ax.set_xlim(46., max([*N1, *N4]))
    #ax.set_xlim(48.5, 50.5)
plt.show()

# %%
H.Unitless()
tferm = H.vals["tferm"]
t = H.vals["t"]

# %%
plt.plot(N2, t-tferm)
plt.ylim(-1,2.)
plt.xlim(46., max([*N1, *N4]))

# %%
kSferm = CubicSpline(t, kS)(tferm)

# %%
plt.plot(N2, np.log(kSferm/kh2))
plt.xlim(46., max([*N1, *N4]))
plt.ylim(-0.5, 0.5)

# %%
plt.plot(N2, abs(delta2-CubicSpline(N3, delta3)(N2)))
plt.yscale("log")

# %%
plt.plot(N2, np.zeros(kh2.size), "k-")
plt.plot(N2, np.log(khO/kh2), "r.", label="khO")
plt.plot(N2, np.log(khE/kh2), "b.", label="khE")
#plt.plot(N2, khO/kh2, "b:", label="khO")
#plt.plot(N2, kS/kh2, "g:", label="kS")
plt.legend(loc=0)
#plt.yscale("log")
#plt.xlim(48.5, 49.25)
plt.ylim(-0.5, 0.5)
plt.show()

# %%
plt.plot(N2, np.zeros(kh2.size), "k-")
plt.plot(N2, np.log(khE/khO), "r:", label="khE")
#plt.plot(N2, khO/kh2, "b:", label="khO")
#plt.plot(N2, kS/kh2, "g:", label="kS")
plt.legend(loc=0)
#plt.yscale("log")
#plt.xlim(48.5, 50.5)
plt.ylim(-1e-2, 1)
plt.show()

# %%
plt.plot(N2, kh2, "k")
plt.plot(N2, khE, "b:")
plt.plot(N2, khO, "r:")
plt.plot(N2, kS, "g:")
plt.plot(N2, np.exp(N2))
plt.xlim(48.5, 62)
plt.yscale("log")
plt.ylim(1e15, 1e23)
plt.show()

# %%
np.where(abs(N2-48.7)<1e-2)[0][0]

# %%
H.Unitless()
H.CreateDeltaFunction()
delta = H.deltaf(H.vals["t"])
plt.plot(N3, delta)
plt.plot(N2, delta2, "k:")
plt.plot(N3, delta3, "r:")

# %%
H.Unitless()
H.SaveData()

# %%
H.Unitless()

ts = H.vals["t"]
kh = H.vals["kh"]
kS = H.vals["kS"]
sE = H.vals["sigmaE"]

sigmaf = CubicSpline(ts, sE)
khf = CubicSpline(ts, kh)
kSf = CubicSpline(ts, kS)
integral = []

for t in ts:
    f = lambda x: np.log(kSf(x)/khf(t))
    x = fsolve(f, t, xtol=1e-5)[0]
    #print(x)
    if (x<t):
        integral.append(quad(sigmaf, x, t)[0])
    else:
        integral.append(0.)
        
integral = np.array(integral)
delta = np.exp(-integral)
    
plt.plot(N2, delta)
plt.plot(N2, delta2, "k:")

# %%
names = ["t", "N", "a", "dphi", "kh", "kS", "sigmaE", "E", "B", "G"]

val = [H.vals[name] for name in names]

data = dict(zip(names, val))
DirName = os.getcwd()
filename = "GEF_beta25_KDepSE.dat"
            
path = os.path.join(DirName, filename)

output_df = pd.DataFrame(data)  
output_df.to_csv(path)

# %%
G.Unitless()
N = G.vals["N"]
t = G.vals["t"]
H = G.vals["H"]
E0 = G.vals["E"]
B0 = G.vals["B"]
xi = G.vals["xieff"]
a = G.vals["a"]
mu = ((E0+B0)/2)**(1/4)*G.H0
print(F.H0)
mz = 91.2/(1.220932e19)
gmz = 0.35
gmu = np.sqrt(gmz**2/(1 + gmz**2*41./(48.*np.pi**2)*np.log(mz/(mu))))
ks = a*np.sqrt(abs(gmu*E0**(1/2)))
khE = G.vals["kh"]
khO = 2*a*H*abs(xi)
plt.plot(N, ks, "g-")
plt.plot(N, khE, "b-")
plt.plot(N, khO, "r-")
plt.yscale("log")
plt.show()

plt.plot(t, ks, "g-")
plt.plot(t, khE, "b-")
plt.plot(t, khO, "r-")
plt.yscale("log")
plt.show()

# %%
plt.plot(N, ks/khE, "b-", label="ks/khE")
plt.plot(N, ks/khO, "r-", label="ks/khO")
plt.plot(N, khE/khO, "g-", label="khE/khO")
plt.legend(loc=0)
plt.show()

plt.plot(t, ks/khE, "b-", label="ks/khE")
plt.plot(t, ks/khO, "r-", label="ks/khO")
plt.plot(t, khE/khO, "g-", label="khE/khO")
plt.legend(loc=0)
plt.show()

# %%
F.Unitless()
H = F.vals["H"]
E0 = F.vals["E"]
B0 = F.vals["B"]
mu = ((E0+B0)/2)**(1/4)*F.H0
print(F.H0)
mz = 91.2/(1.220932e19)
gmz = 0.35
gmu = np.sqrt(gmz**2/(1 + gmz**2*41./(48.*np.pi**2)*np.log(mz/(mu))))
kh = np.log(F.vals["kh"])
print(kh)
k1 = 0.25*np.log(E0) - kh + 0.5*np.log(gmu) + N1
for i in range(len(k1)):
    if k1[i] < 0.:
        k1[i] = 0.

                
k1 = k1/H

plt.plot(F.vals["t"], k1)
plt.vlines(67., 0., 25)
plt.vlines(100., 0., 25)
plt.show()

plt.plot(F.vals["N"], k1)
plt.show()

k = CubicSpline(F.vals["t"], k1)
print(k(67.))
print(k(97.))
print((k(117)-k(67))/50.)

"""plt.plot(F.vals["t"], k1, "r-")
plt.plot(F.vals["t"], H)
#plt.xlim(45., 62)
plt.show()"""

"""plt.plot(F.vals["t"], F.vals["t"] - k1/H*F.H0, "r-")
plt.plot(F.vals["t"], F.vals["t"])
#lt.xlim(51., max([*N1, *N4]))
#plt.plot(N1, np.zeros(N1.size))
#plt.xlim(45., 62)
#plt.ylim(-0.01e6,0.2e6)
plt.show()

plt.plot(F.vals["t"], - k1/H*F.H0/F.vals["t"], "r-")
#lt.xlim(51., max([*N1, *N4]))
plt.plot(F.vals["t"], np.zeros(N1.size))
plt.vlines(69, -0.035, 0.001)
#plt.xlim(45., 62)
#plt.ylim(-0.01e6,0.2e6)
plt.show()"""

# %%
plt.plot(F.vals["N"][1:], ((k1[1:]-k1[:-1])/(F.vals["t"][1:] - F.vals["t"][:-1])), "b-")
#plt.plot(F.vals["t"][1:], F.vals["sigmaE"][1:]/(2*H[1:]), "r-")
plt.plot(F.vals["N"], np.ones(F.vals["t"].shape)*0.27, "r-")
#plt.plot(F.vals["t"], H/F.H0)
plt.xlim(45., 62)
plt.show()

# %%
a = np.arange(1,5)
print(a)
print(a[0:])

# %%
a = 0.
if (not(a)):
    print(a)

# %%
plt.plot(np.linspace(1, 100, 100), np.zeros(100))
plt.plot(np.linspace(1, 100, 100), np.ones(100))
plt.plot(np.linspace(1, 100, 100), 2*np.ones(100))
