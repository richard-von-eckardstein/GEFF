# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from importlib import reload
import GEFv15
reload(GEFv15)
from GEFv15 import GEF
#from GEF import GEF as GEF2
from utilities import PlotComp
from scipy.interpolate import CubicSpline, RectBivariateSpline
from scipy.integrate import quad
from scipy.optimize import fsolve
import os
from utilities import PlotComp, EndOfInflation2

# %%
name = "Out/GEF_Beta25.0_SE-1.0_KDep_RhoDamp8"

# %%
alpha = 0.
Mpl = 1.
beta = 25.
M = 6e-6*Mpl
phi0 = 15.55*Mpl
dphidt0 = -np.sqrt(2/3)*M*Mpl
ini = {"phi":phi0, "dphi":dphidt0, "delta":1.0, "rhoChi":0.0}
SE = -1.0
ntr = 55
H = GEF(alpha, beta, Mpl, ini, M, ntr, SE, AltDamp=2, approx=True)
t1 = 120

# %%
print(H.H0)
# Out:
# 3.814203717684728e-05

# %%
sol = H.RunGEF(t1=t1)
print(sol.success)
# Out:
# Elapsed time: 244.7154 seconds
# success: True
# True

# %%
print(H.vals["N"], H.vals["t"])
# Out:
# [0.00000000e+00 3.85010640e-32 4.23511704e-31 ... 6.13309891e+01
#  6.13364677e+01 6.13388497e+01] [0.00000000e+00 3.85010640e-32 4.23511704e-31 ... 1.19846466e+02
#  1.19953233e+02 1.20000000e+02]

# %%
print(sol.success)
# Out:
# True

# %%
H.Unitful()
Nend = EndOfInflation2(H.vals["N"], H.vals["dphi"], H.potential(), H.vals["E"], H.vals["B"], H.vals["rhoChi"], H.H0, tol=1e-4)
print(H.vals["N"][-1])
# Out:
# 61.01610100275927
# 61.338849675346744

# %%
H.Unitless()
file = name+"_0it.dat"
H.SaveData(outdir=file)
# Out:
# Already Unitless

# %%
H.Unitful()

t3 = H.vals["t"]
N3 = H.vals["N"]
xi3 = H.vals["xi"]
xieff3 = H.vals["xieff"]
dphi3 = H.vals["dphi"]
H3 = H.vals["H"]
delta3 = H.vals["delta"]
rhoChi3 = H.vals["rhoChi"]
E3= H.vals["E"]
B3 = H.vals["B"]
G3 = H.vals["G"]
sE3 = H.vals["sigmaE"]
s3 = H.vals["s"]
sEk3 = H.vals["sigmaEk"]
sk3 = H.vals["sk"]
kh3 = H.vals["kh"]

# %%
plt.plot(N3, E3)
plt.plot(N3, B3)
plt.plot(N3, abs(G3))
plt.yscale("log")
plt.ylim(1e-17, 1e-13)
plt.xlim(45,62)
# Out:
# (45.0, 62.0)

# %%
plt.plot(N3, np.log(kh3/H.vals["kS"]), "r")
#plt.plot(N3, H.vals["khE"], "m:", label="khE")
#plt.plot(t3*H.H0, H.vals["khO"], "c:", label="khO")
#plt.plot(t3*H.H0, H.vals["khL"], "y:", label="khL")
plt.plot(N3, np.zeros(N3.shape), "g", label="kS")
#plt.yscale("log")
plt.ylim(-1, 1)
#plt.xlim(49,51)
# Out:
# (-1.0, 1.0)

# %%
H.LoadData(name+"_0it.dat")

# %%
H.ntr=125
t1 = 118.5

# %%
H.IterateGEF(t1=t1)
# Out:
# Already Unitless
# /home/users/rfreiher/.conda/envs/ptarcade/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:177: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# /home/users/rfreiher/Documents/Axion_Inflation/GEF/GEFv15.py:619: RuntimeWarning: invalid value encountered in log
#   f = lambda x: np.log(kSf(x)/khf(ts[i]))
# /home/users/rfreiher/.conda/envs/ptarcade/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:177: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# delta function created, access using x.deltaf
# Elapsed time: 994.0843 seconds
# success: True
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  2.574e-67 ...  1.185e+02  1.185e+02]
#         y: [[ 0.000e+00  2.574e-67 ...  6.125e+01  6.126e+01]
#             [ 1.555e+01  1.555e+01 ...  6.328e-01  6.276e-01]
#             ...
#             [ 0.000e+00  1.429e-03 ...  1.053e+68  2.165e+68]
#             [ 0.000e+00 -2.240e-04 ...  9.403e+67  1.730e+68]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 17540
#      njev: 0
#       nlu: 0

# %%
print(H.vals["t"], H.vals["N"])
# Out:
# [0.00000000e+00 2.57443989e-67 2.83188387e-66 ... 1.18393940e+02
#  1.18450413e+02 1.18500000e+02] [0.00000000e+00 2.57443989e-67 2.83188387e-66 ... 6.12508944e+01
#  6.12542286e+01 6.12571419e+01]

# %%
H.Unitful()
Nend = EndOfInflation2(H.vals["N"], H.vals["dphi"], H.potential(), H.vals["E"], H.vals["B"], H.vals["rhoChi"], H.H0, tol=1e-4)
print(H.vals["N"][-1])
# Out:
# 61.01659848186494
# 61.257141948912725

# %%
H.Unitless()
file = name+"_1it.dat"
H.SaveData(outdir=file)
# Out:
# Already Unitless

# %%
H.LoadData(name+"_1it.dat")

# %%
H.ntr=125
t1 = 119

# %%
H.IterateGEF(t1=t1)
# Out:
# Already Unitless
# delta function created, access using x.deltaf
# /home/users/rfreiher/.conda/envs/ptarcade/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:177: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# /home/users/rfreiher/Documents/Axion_Inflation/GEF/GEFv15.py:592: RuntimeWarning: invalid value encountered in log
#   f = lambda x: np.log(kSf(x)/khf(ts[i]))
# /home/users/rfreiher/.conda/envs/ptarcade/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:177: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# Elapsed time: 413.3440 seconds
# success: True
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  2.574e-67 ...  1.190e+02  1.190e+02]
#         y: [[ 0.000e+00  2.574e-67 ...  6.129e+01  6.129e+01]
#             [ 1.555e+01  1.555e+01 ...  5.771e-01  5.759e-01]
#             ...
#             [ 0.000e+00  1.429e-03 ...  2.101e+68  2.445e+68]
#             [ 0.000e+00 -2.240e-04 ...  1.905e+68  2.134e+68]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 17912
#      njev: 0
#       nlu: 0

# %%
print(H.vals["N"])
# Out:
# [0.00000000e+00 2.57443989e-67 2.83188387e-66 ... 6.12826073e+01
#  6.12850904e+01 6.12857351e+01]

# %%
H.Unitful()
Nend = EndOfInflation2(H.vals["N"], H.vals["dphi"], H.potential(), H.vals["E"], H.vals["B"], H.vals["rhoChi"], H.H0, tol=1e-4)
print(H.vals["N"][-1])
# Out:
# 61.01648940182288
# 61.28573509599754

# %%
H.Unitless()
file = name+"_2it.dat"
H.SaveData(outdir=file)
# Out:
# Already Unitless

# %%
H.Unitful()

t2 = H.vals["t"]
N2 = H.vals["N"]
xi2 = H.vals["xi"]
xieff2 = H.vals["xieff"]
dphi2 = H.vals["dphi"]
H2 = H.vals["H"]
delta2 = H.vals["delta"]
rhoChi2 = H.vals["rhoChi"]
E2= H.vals["E"]
B2 = H.vals["B"]
G2 = H.vals["G"]
sE2 = H.vals["sigmaE"]
s2 = H.vals["s"]
sEk2 = H.vals["sigmaEk"]
sk2 = H.vals["sk"]
kh2 = H.vals["kh"]

# %%
fig, ax = plt.subplots(5,2, figsize=(10,10), sharex=True)

ax[0,0].plot(N2, xi2, "g-", label="K-Dependant Delta 2 It")
ax[0,0].plot(N3, xi3, "c:", label="K-Dependant Delta")
ax[0,0].set_ylabel(r"$\xi$")

ax[0,1].plot(N2, dphi2, "g-")
ax[0,1].plot(N3, dphi3, "c:")
ax[0,1].set_ylabel(r"$\dot{\phi}$")
#ax[0,1].set_ylabel(r"$\xi_{eff}$")

ax[1,0].plot(N2, delta2, "g-")
ax[1,0].plot(N3, delta3, "c:")
ax[1,0].set_ylabel(r"$\Delta$")


ax[1,1].plot(N2, H2, "g-")
ax[1,1].plot(N3, H3, "c:")
ax[1,1].set_ylabel(r"$H$")

ax[2,0].plot(N2, E2, "g-")
ax[2,0].plot(N3, E3, "c:")
ax[2,0].set_ylabel(r"$E$")
ax[2,0].set_yscale("log")

ax[2,1].plot(N2, B2, "g-")
ax[2,1].plot(N3, B3, "c:")
ax[2,1].set_ylabel(r"$B$")
ax[2,1].set_yscale("log")

ax[3,0].plot(N2, rhoChi2, "g-")
ax[3,0].plot(N3, rhoChi3, "c:")
ax[3,0].set_ylabel(r"$\rho_\chi$")
ax[3,0].set_yscale("log")

ax[3,1].plot(N2, abs(G2), "g-")
ax[3,1].plot(N3, abs(G3), "c:")
ax[3,1].set_ylabel(r"$G$")
ax[3,1].set_yscale("log")

ax[4,0].plot(N2, sE2, "g-")
ax[4,0].plot(N2, sEk2, "g-")
ax[4,0].plot(N3, sEk3, "c:")
ax[4,0].plot(N3, sE3, "c:")
ax[4,0].set_ylabel(r"$\sigma_E$")
ax[4,0].set_yscale("log")

ax[4,1].plot(N2, s2, "g-")
ax[4,1].plot(N2, sk2, "g-")
ax[4,1].plot(N3, sk3, "c:")
ax[4,1].plot(N3, s3, "c:")
ax[4,1].set_ylabel(r"$s$")
#ax[4,1].set_yscale("log")

lines_labels = [ax[0,0].get_legend_handles_labels()]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels)

"""ax[0,0].set_ylim(-0.5,10)
ax[2,0].set_ylim(-4.5e-6,1e-6)
ax[4,0].set_ylim(-20,20)
ax[4,0].set_ylim(1e7, 2e18)"""

#ax[0,1].set_ylim(1e13, 1e23)
ax[2,0].set_ylim(1e-17, 2.5e-13)
ax[2,1].set_ylim(1e-17, 2.5e-13)
ax[3,0].set_ylim(1e-17, 2.5e-13)
ax[3,1].set_ylim(1e-17, 2.5e-13)
ax[4,0].set_ylim(5e-7, 1e-3)
#ax[4,1].set_ylim(1e-6, 8e-3)

for ax in fig.axes:
    ax.grid(True)
    ax.set_xlim(46., max([*N2, *N3]))
    #ax.set_xlim(48.5, 50.5)
plt.show()

# %%
plt.plot(N2, H.vals["tferm"])

# %%
H.Unitless()
t = H.vals["t"]
a = H.vals["a"]
N = H.vals["N"]
khO = H.vals["khO"]
khE = H.vals["khE"]
ks = H.vals["kS"]
kh = H.vals["kh"]
plt.plot(N, khE/a, "c:")
plt.plot(N, khO/a, "m:")
plt.plot(N, ks/a, "g")
plt.plot(N, kh/a, "r")
#plt.plot(N, np.log(ks/kh))
plt.ylim(-1,7.5)
#plt.xlim(46, 60)
# Out:
# Already Unitless
# (46.0, 60.0)

# %%
plt.plot(N, khO, "c:")
plt.plot(N, khE, "m:")
plt.plot(N, ks, "g")
plt.plot(N, kh, "r")
plt.yscale("log")
plt.ylim(1e18, 1e27)
plt.xlim(46, 60)
# Out:
# (46.0, 60.0)

# %%
xi = H.vals["xi"]
xieff = H.vals["xieff"]
plt.plot(N, xi, "r")
plt.plot(N, xieff, "g:")
plt.xlim(46, 62)
plt.ylim(-22.5, 0.0)
plt.show()

# %%
plt.plot(N, H.vals["sigmaE"]/(2*H.vals["H"]))
plt.plot(N, H.vals["sigmaEk"]/(2*H.vals["H"]))
plt.xlim(46, 62)
plt.yscale("log")

# %%
E = H.vals["E"]
G = abs(H.vals["G"])
B = H.vals["B"]
plt.plot(N, E, "b")
plt.plot(N, B, "r")
plt.plot(N, G, "g")
plt.yscale("log")
plt.xlim(46, 62)
plt.ylim(1e0, 1e5)
plt.show()

# %%
H.CreateDeltaFunction()
# Out:
# /home/users/rfreiher/Documents/Axion_Inflation/GEF/GEFv3.py:753: RuntimeWarning: invalid value encountered in log
#   f = lambda x: np.log(kSf(x)/khf(ts[i]))
# /home/users/rfreiher/.conda/envs/ptarcade/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:177: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# delta function created, access using x.deltaf

# %%
plt.plot(N, H.vals["delta"], "g")
plt.plot(N, H.deltaf(H.vals["t"]), "r")
plt.xlim(46, 62)
plt.show()

# %%
tferm = H.vals["tferm"]

plt.plot(t, H.Bmf(t), "b-")
plt.plot(t, H.Bmf2(t), "b:")
plt.plot(t, np.log(ks/kh), "c:")
plt.plot(t, np.zeros(t.shape), "k:")
plt.plot(t, t-tferm, "m:")
#plt.yscale("log")
plt.ylim(-2,25)
# Out:
# (-2.0, 25.0)

# %%
sol = H.IterateGEF(t1=114.)
# Out:
# /home/richard/Documents/Phd Muenster/Axions in the early Universe/GEF/GEFv4.py:755: RuntimeWarning: invalid value encountered in log
#   f = lambda x: np.log(kSf(x)/khf(ts[i]))
# /home/richard/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# delta function created, access using x.deltaf
# Elapsed time: 6.6358 seconds

# %%
print(sol)
# Out:
#   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 8468
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([0.00000000e+00, 4.63266721e-32, 5.09593393e-31, ...,
#        1.13897182e+02, 1.13998225e+02, 1.14000000e+02])
#  t_events: None
#         y: array([[ 0.00000000e+00,  4.63266721e-32,  5.09593393e-31, ...,
#          6.09268951e+01,  6.09355790e+01,  6.09357309e+01],
#        [ 1.55500000e+01,  1.55500000e+01,  1.55500000e+01, ...,
#          1.13134717e+00,  1.11988009e+00,  1.11967875e+00],
#        [-1.28440426e-01, -1.28440426e-01, -1.28440426e-01, ...,
#         -1.13565104e-01, -1.13410194e-01, -1.13407453e-01],
#        ...,
#        [ 0.00000000e+00,  7.31223767e-36,  8.84780758e-34, ...,
#         -1.22881595e+21,  1.97569318e+21,  2.02885435e+21],
#        [ 0.00000000e+00, -1.53183385e-03, -1.68501724e-02, ...,
#         -5.01634472e+23, -4.83162003e+23, -4.82780533e+23],
#        [ 0.00000000e+00,  3.94598373e-04,  4.34058210e-03, ...,
#         -1.71535030e+23, -1.62185851e+23, -1.62010047e+23]])
#  y_events: None

# %%
#H.Unitful()
omega=H.H0

file = "Out/GEF_Beta25.0_SE-1.0_KDep_5it.dat"
input_df = pd.read_table(file, sep=",")
data = dict(zip(input_df.columns[1:],input_df.values[1:,1:].T))

N4 = data["N"]
xi4 = data["xi"]
xieff4 = data["xieff"]
dphi4 = data["dphi"]*omega
delta4 = data["delta"]
H4 = data["H"]*omega
rhoChi4 = data["rhoChi"]*omega**4
E4 = data["E"]*omega**4
B4 = data["B"]*omega**4
G4 = data["G"]*omega**4
sE4 = data["sigmaE"]*omega
s4 = data["s"]
kh4 = data["kh"]*omega

t2 = H.vals["t"]
N2 = H.vals["N"]
xi2 = H.vals["xi"]
xieff2 = H.vals["xieff"]
dphi2 = H.vals["dphi"]
H2 = H.vals["H"]
delta2 = H.vals["delta"]
rhoChi2 = H.vals["rhoChi"]
E2= H.vals["E"]
B2 = H.vals["B"]
G2 = H.vals["G"]
sE2 = H.vals["sigmaE"]
s2 = H.vals["s"]
kh2 = H.vals["kh"]
khE = H.vals["khE"]
khO = H.vals["khO"]
kS = H.vals["kS"]

# %%
H.IterateGEF(t1=114.)
# Out:
# Already Unitless
# /home/richard/Documents/Phd Muenster/Axions in the early Universe/GEF/GEFv4.py:755: RuntimeWarning: invalid value encountered in log
#   f = lambda x: np.log(kSf(x)/khf(ts[i]))
# /home/richard/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# /home/richard/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# delta function created, access using x.deltaf
# Elapsed time: 6.7623 seconds
#   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 8414
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([0.00000000e+00, 4.63266721e-32, 5.09593393e-31, ...,
#        1.13863984e+02, 1.13979995e+02, 1.14000000e+02])
#  t_events: None
#         y: array([[ 0.00000000e+00,  4.63266721e-32,  5.09593393e-31, ...,
#          6.09236769e+01,  6.09336639e+01,  6.09353772e+01],
#        [ 1.55500000e+01,  1.55500000e+01,  1.55500000e+01, ...,
#          1.13471049e+00,  1.12153919e+00,  1.11927005e+00],
#        [-1.28440426e-01, -1.28440426e-01, -1.28440426e-01, ...,
#         -1.13623407e-01, -1.13446065e-01, -1.13415212e-01],
#        ...,
#        [ 0.00000000e+00,  7.31223767e-36,  8.84780758e-34, ...,
#          2.76676237e+21,  1.69646673e+21,  1.49875187e+21],
#        [ 0.00000000e+00, -1.53183385e-03, -1.68501724e-02, ...,
#         -1.77223584e+23, -1.59870928e+23, -1.56885899e+23],
#        [ 0.00000000e+00,  3.94598373e-04,  4.34058210e-03, ...,
#         -5.74902367e+22, -4.81101038e+22, -4.64848544e+22]])
#  y_events: None

# %%
H.Unitful()

t1 = H.vals["t"]
N1 = H.vals["N"]
xi1 = H.vals["xi"]
xieff1 = H.vals["xieff"]
dphi1 = H.vals["dphi"]
H1 = H.vals["H"]
delta1 = H.vals["delta"]
rhoChi1 = H.vals["rhoChi"]
E1= H.vals["E"]
B1 = H.vals["B"]
G1 = H.vals["G"]
sE1 = H.vals["sigmaE"]
s1 = H.vals["s"]
kh1 = H.vals["kh"]

# %%
fig, ax = plt.subplots(5,2, figsize=(10,10), sharex=True)

ax[0,0].plot(N4, xi4, "b:", label="Old Delta")
ax[0,0].plot(N1, xi1, "r:", label="K-Dependant Delta 2 It")
ax[0,0].plot(N2, xi2, "g-", label="K-Dependant Delta 1 It")
ax[0,0].plot(N3, xi3, "c:", label="K-Dependant Delta")
ax[0,0].set_ylabel(r"$\xi$")


ax[0,1].plot(N4, dphi4, "b:")
ax[0,1].plot(N1, dphi1, "r:")
ax[0,1].plot(N2, dphi2*omega, "g-")
ax[0,1].plot(N3, dphi3, "c:")
ax[0,1].set_ylabel(r"$\dot{\phi}$")
#ax[0,1].set_ylabel(r"$\xi_{eff}$")

ax[1,0].plot(N4, delta4, "b:")
ax[1,0].plot(N1, delta1, "r:")
ax[1,0].plot(N2, delta2, "g-")
ax[1,0].plot(N3, delta3, "c:")
ax[1,0].set_ylabel(r"$\Delta$")

ax[1,1].plot(N4, H4, "b:")
ax[1,1].plot(N1, H1, "r:")
ax[1,1].plot(N2, H2*omega, "g-")
ax[1,1].plot(N3, H3, "c:")
ax[1,1].set_ylabel(r"$H$")

ax[2,0].plot(N4, E4, "b:")
ax[2,0].plot(N1, E1, "r:")
ax[2,0].plot(N2, E2*omega**4, "g-")
ax[2,0].plot(N3, E3, "c:")
ax[2,0].set_ylabel(r"$E$")
ax[2,0].set_yscale("log")

ax[2,1].plot(N4, B4, "b:")
ax[2,1].plot(N1, B1, "r:")
ax[2,1].plot(N2, B2*omega**4, "g-")
ax[2,1].plot(N3, B3, "c:")
ax[2,1].set_ylabel(r"$B$")
ax[2,1].set_yscale("log")

ax[3,0].plot(N4, rhoChi4, "b:")
ax[3,0].plot(N1, rhoChi1, "r:")
ax[3,0].plot(N2, rhoChi2*omega**4, "g-")
ax[3,0].plot(N3, rhoChi3, "c:")
ax[3,0].set_ylabel(r"$\rho_\chi$")
ax[3,0].set_yscale("log")

ax[3,1].plot(N4, abs(G4), "b:")
ax[3,1].plot(N1, abs(G1), "r:")
ax[3,1].plot(N2, abs(G2)*omega**4, "g-")
ax[3,1].plot(N3, abs(G3), "c:")
ax[3,1].set_ylabel(r"$G$")
ax[3,1].set_yscale("log")

ax[4,0].plot(N4, sE4, "b:")
ax[4,0].plot(N1, sE1, "r:")
ax[4,0].plot(N2, sE2*omega, "g-")
#ax[4,0].plot(N2, sEk, "g-")
#ax[4,0].plot(N3, sEk3, "c:")
ax[4,0].plot(N3, sE3, "c:")
ax[4,0].set_ylabel(r"$\sigma_E$")
ax[4,0].set_yscale("log")

ax[4,1].plot(N4, s4, "b:")
ax[4,1].plot(N1, s1, "r:")
ax[4,1].plot(N2, s2, "g-")
#ax[4,1].plot(N2, sk, "g-")
#ax[4,1].plot(N3, sk3, "c:")
ax[4,1].plot(N3, s3, "c:")
ax[4,1].set_ylabel(r"$s$")
#ax[4,1].set_yscale("log")

lines_labels = [ax[0,0].get_legend_handles_labels()]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels)

"""ax[0,0].set_ylim(-0.5,10)
ax[2,0].set_ylim(-4.5e-6,1e-6)
ax[4,0].set_ylim(-20,20)
ax[4,0].set_ylim(1e7, 2e18)"""

#ax[0,1].set_ylim(1e13, 1e23)
ax[2,0].set_ylim(1e-17, 2.5e-13)
ax[2,1].set_ylim(1e-17, 2.5e-13)
ax[3,0].set_ylim(1e-17, 2.5e-13)
ax[3,1].set_ylim(1e-17, 2.5e-13)
ax[4,0].set_ylim(5e-7, 1e-3)
#ax[4,1].set_ylim(1e-6, 8e-3)

for ax in fig.axes:
    ax.grid(True)
    ax.set_xlim(46., max([*N1, *N4]))
    #ax.set_xlim(48.5, 50.5)
plt.show()

# %%
H.Unitless()
tferm = H.vals["tferm"]
t = H.vals["t"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 2
#       1 H.Unitless()
# ----> 2 tferm = H.vals["tferm"]
#       3 t = H.vals["t"]
#
# KeyError: 'tferm'

# %%
plt.plot(N2, t-tferm)
plt.ylim(-1,2.)
plt.xlim(46., max([*N1, *N4]))
# Out:
# (46.0, 61.36107794482943)

# %%
kSferm = CubicSpline(t, kS)(tferm)

# %%
plt.plot(N2, np.log(kSferm/kh2))
plt.xlim(46., max([*N1, *N4]))
plt.ylim(-0.5, 0.5)
# Out:
# /tmp/ipykernel_15002/3354485261.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(N2, np.log(kSferm/kh2))
# /tmp/ipykernel_15002/3354485261.py:1: RuntimeWarning: invalid value encountered in log
#   plt.plot(N2, np.log(kSferm/kh2))
# (-0.5, 0.5)

# %%
plt.plot(N2, abs(delta2-CubicSpline(N3, delta3)(N2)))
plt.yscale("log")

# %%
plt.plot(N2, np.zeros(kh2.size), "k-")
plt.plot(N2, np.log(khO/kh2), "r.", label="khO")
plt.plot(N2, np.log(khE/kh2), "b.", label="khE")
#plt.plot(N2, khO/kh2, "b:", label="khO")
#plt.plot(N2, kS/kh2, "g:", label="kS")
plt.legend(loc=0)
#plt.yscale("log")
#plt.xlim(48.5, 49.25)
plt.ylim(-0.5, 0.5)
plt.show()

# %%
plt.plot(N2, np.zeros(kh2.size), "k-")
plt.plot(N2, np.log(khE/khO), "r:", label="khE")
#plt.plot(N2, khO/kh2, "b:", label="khO")
#plt.plot(N2, kS/kh2, "g:", label="kS")
plt.legend(loc=0)
#plt.yscale("log")
#plt.xlim(48.5, 50.5)
plt.ylim(-1e-2, 1)
plt.show()

# %%
plt.plot(N2, kh2, "k")
plt.plot(N2, khE, "b:")
plt.plot(N2, khO, "r:")
plt.plot(N2, kS, "g:")
plt.plot(N2, np.exp(N2))
plt.xlim(48.5, 62)
plt.yscale("log")
plt.ylim(1e15, 1e23)
plt.show()

# %%
np.where(abs(N2-48.7)<1e-2)[0][0]

# %%
H.Unitless()
H.CreateDeltaFunction()
delta = H.deltaf(H.vals["t"])
plt.plot(N3, delta)
plt.plot(N2, delta2, "k:")
plt.plot(N3, delta3, "r:")
# Out:
# Already Unitless
# delta function created, access using x.deltaf

# %%
H.Unitless()
H.SaveData()

# %%
H.Unitless()

ts = H.vals["t"]
kh = H.vals["kh"]
kS = H.vals["kS"]
sE = H.vals["sigmaE"]

sigmaf = CubicSpline(ts, sE)
khf = CubicSpline(ts, kh)
kSf = CubicSpline(ts, kS)
integral = []

for t in ts:
    f = lambda x: np.log(kSf(x)/khf(t))
    x = fsolve(f, t, xtol=1e-5)[0]
    #print(x)
    if (x<t):
        integral.append(quad(sigmaf, x, t)[0])
    else:
        integral.append(0.)
        
integral = np.array(integral)
delta = np.exp(-integral)
    
plt.plot(N2, delta)
plt.plot(N2, delta2, "k:")

# %%
names = ["t", "N", "a", "dphi", "kh", "kS", "sigmaE", "E", "B", "G"]

val = [H.vals[name] for name in names]

data = dict(zip(names, val))
DirName = os.getcwd()
filename = "GEF_beta25_KDepSE.dat"
            
path = os.path.join(DirName, filename)

output_df = pd.DataFrame(data)  
output_df.to_csv(path)

# %%
G.Unitless()
N = G.vals["N"]
t = G.vals["t"]
H = G.vals["H"]
E0 = G.vals["E"]
B0 = G.vals["B"]
xi = G.vals["xieff"]
a = G.vals["a"]
mu = ((E0+B0)/2)**(1/4)*G.H0
print(F.H0)
mz = 91.2/(1.220932e19)
gmz = 0.35
gmu = np.sqrt(gmz**2/(1 + gmz**2*41./(48.*np.pi**2)*np.log(mz/(mu))))
ks = a*np.sqrt(abs(gmu*E0**(1/2)))
khE = G.vals["kh"]
khO = 2*a*H*abs(xi)
plt.plot(N, ks, "g-")
plt.plot(N, khE, "b-")
plt.plot(N, khO, "r-")
plt.yscale("log")
plt.show()

plt.plot(t, ks, "g-")
plt.plot(t, khE, "b-")
plt.plot(t, khO, "r-")
plt.yscale("log")
plt.show()
# Out:
# 3.814203717684728e-05
# /tmp/ipykernel_17055/2738743542.py:13: RuntimeWarning: divide by zero encountered in divide
#   gmu = np.sqrt(gmz**2/(1 + gmz**2*41./(48.*np.pi**2)*np.log(mz/(mu))))

# %%
plt.plot(N, ks/khE, "b-", label="ks/khE")
plt.plot(N, ks/khO, "r-", label="ks/khO")
plt.plot(N, khE/khO, "g-", label="khE/khO")
plt.legend(loc=0)
plt.show()

plt.plot(t, ks/khE, "b-", label="ks/khE")
plt.plot(t, ks/khO, "r-", label="ks/khO")
plt.plot(t, khE/khO, "g-", label="khE/khO")
plt.legend(loc=0)
plt.show()

# %%
F.Unitless()
H = F.vals["H"]
E0 = F.vals["E"]
B0 = F.vals["B"]
mu = ((E0+B0)/2)**(1/4)*F.H0
print(F.H0)
mz = 91.2/(1.220932e19)
gmz = 0.35
gmu = np.sqrt(gmz**2/(1 + gmz**2*41./(48.*np.pi**2)*np.log(mz/(mu))))
kh = np.log(F.vals["kh"])
print(kh)
k1 = 0.25*np.log(E0) - kh + 0.5*np.log(gmu) + N1
for i in range(len(k1)):
    if k1[i] < 0.:
        k1[i] = 0.

                
k1 = k1/H

plt.plot(F.vals["t"], k1)
plt.vlines(67., 0., 25)
plt.vlines(100., 0., 25)
plt.show()

plt.plot(F.vals["N"], k1)
plt.show()

k = CubicSpline(F.vals["t"], k1)
print(k(67.))
print(k(97.))
print((k(117)-k(67))/50.)

"""plt.plot(F.vals["t"], k1, "r-")
plt.plot(F.vals["t"], H)
#plt.xlim(45., 62)
plt.show()"""

"""plt.plot(F.vals["t"], F.vals["t"] - k1/H*F.H0, "r-")
plt.plot(F.vals["t"], F.vals["t"])
#lt.xlim(51., max([*N1, *N4]))
#plt.plot(N1, np.zeros(N1.size))
#plt.xlim(45., 62)
#plt.ylim(-0.01e6,0.2e6)
plt.show()

plt.plot(F.vals["t"], - k1/H*F.H0/F.vals["t"], "r-")
#lt.xlim(51., max([*N1, *N4]))
plt.plot(F.vals["t"], np.zeros(N1.size))
plt.vlines(69, -0.035, 0.001)
#plt.xlim(45., 62)
#plt.ylim(-0.01e6,0.2e6)
plt.show()"""
# Out:
# 3.814203717684728e-05
# [ 1.16658573  1.16658573  1.16658573 ... 62.43309273 62.45342685
#  62.45897793]
# /tmp/ipykernel_17055/3359179201.py:9: RuntimeWarning: divide by zero encountered in divide
#   gmu = np.sqrt(gmz**2/(1 + gmz**2*41./(48.*np.pi**2)*np.log(mz/(mu))))
# /tmp/ipykernel_17055/3359179201.py:12: RuntimeWarning: divide by zero encountered in log
#   k1 = 0.25*np.log(E0) - kh + 0.5*np.log(gmu) + N1
# 1.1526067083615573e-05
# 5.344922567508573
# 0.2707594813147624
# 'plt.plot(F.vals["t"], F.vals["t"] - k1/H*F.H0, "r-")\nplt.plot(F.vals["t"], F.vals["t"])\n#lt.xlim(51., max([*N1, *N4]))\n#plt.plot(N1, np.zeros(N1.size))\n#plt.xlim(45., 62)\n#plt.ylim(-0.01e6,0.2e6)\nplt.show()\n\nplt.plot(F.vals["t"], - k1/H*F.H0/F.vals["t"], "r-")\n#lt.xlim(51., max([*N1, *N4]))\nplt.plot(F.vals["t"], np.zeros(N1.size))\nplt.vlines(69, -0.035, 0.001)\n#plt.xlim(45., 62)\n#plt.ylim(-0.01e6,0.2e6)\nplt.show()'

# %%
plt.plot(F.vals["N"][1:], ((k1[1:]-k1[:-1])/(F.vals["t"][1:] - F.vals["t"][:-1])), "b-")
#plt.plot(F.vals["t"][1:], F.vals["sigmaE"][1:]/(2*H[1:]), "r-")
plt.plot(F.vals["N"], np.ones(F.vals["t"].shape)*0.27, "r-")
#plt.plot(F.vals["t"], H/F.H0)
plt.xlim(45., 62)
plt.show()

# %%
a = np.arange(1,5)
print(a)
print(a[0:])
# Out:
# [1 2 3 4]
# [1 2 3 4]
