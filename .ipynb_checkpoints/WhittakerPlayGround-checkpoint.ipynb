# %%
import numpy as np
from scipy.special import binom
import matplotlib.pyplot as plt
from mpmath import whitw, besselk
from scipy.integrate import solve_ivp
from scipy.integrate import odeint
from scipy.integrate import quad
import pandas as pd
import math
from scipy.interpolate import CubicSpline
from scipy.interpolate import RectBivariateSpline
from scipy.optimize import fsolve, curve_fit
from timer import Timer
import os
from importlib import reload
import utilities
reload(utilities)
from utilities import EndOfInflation
import GEFv15
reload(GEFv15)
from GEFv15 import GEF

# %%
Q = lambda x, xi, l: np.exp(l*np.pi*xi/2) * complex(whitw(-1j*xi*l, 1/2, -4j*abs(xi)*x))
P = lambda x, xi, l: np.exp(l*np.pi*xi/2) * (complex(whitw(-1j*xi*l, 1/2, -4j*abs(xi)*x))*1j*(1-l/2*np.sign(xi))
                                             + complex(whitw(1-1j*xi*l, 1/2, -4j*abs(xi)*x))/(2*abs(xi)*x))

# %%
Ef = lambda x, xi, l: abs(P(x, xi, l))**2
Bf = lambda x, xi, l: abs(Q(x, xi, l))**2
Gf = lambda x, xi, l: (P(x, xi, l)*Q(x, xi, l).conjugate()).real

# %%
Ef = lambda x, xi, l: np.exp(l*np.pi*xi) * abs((2j*abs(xi) - 1j*xi)*whitw(-1j*xi*l, 1/2, -4j*abs(xi)*x)
                                               + complex(whitw(1-1j*xi*l, 1/2, -4j*abs(xi)*x)))**2/(2*abs(xi))**2
Bf = lambda x, xi, l: np.exp(l*np.pi*xi) * abs( whitw(-1j*xi*l, 1/2, -4j*abs(xi)*x) )**2
Gf = lambda x, xi, l: np.exp(l*np.pi*xi) * abs( whitw(1-1j*xi*l, 1/2, -4j*abs(xi)*x)*whitw(-1j*xi*l, 1/2, -4j*abs(xi)*x).conjugate() 
                                              )**2/(2*abs(xi))

# %%
iE = lambda x, xi, l: x**3*Ef(x, xi, l)
iB = lambda x, xi, l: x**3*Gf(x, xi, l)

def Taylor(xi, pol):
    E = Ef(1, xi, pol)
    G = Gf(1, xi, pol)
    B = Bf(1, xi, pol)

    p = (2*abs(xi) - 2*pol*xi)
    r = 2*abs(xi)
    
    Ep = 2*p*G
    Bp = -2*r*G
    Gp = p*B - r*E

    Ep2 = -2*r*p*E + 2*p**2*B + 4*pol*xi*G
    Bp2 = -2*r*p*B + 2*r**2*E
    Gp2 = 2*pol*xi*B - 4*r*p*G

    Es = np.array([E, Ep, 1/2*Ep2])
    Bs = np.array([B, Bp, 1/2*Bp2])
    Gs = np.array([G, Gp, 1/2*Gp2])

    dic = {"E":Es, "B":Bs, "G":Gs}

    return dic

def IntApprx(xs, xi, l, order=3, n=0):
    ys = 1-xs
    taylor = Taylor(xi, l)
    order = min(len(taylor["E"]), order)
    
    dic = {"E":0, "B":0, "G":0}
    for name in dic.keys():
        for i in range(order):
            for j in range(i):
                dic[name] += (-1)**i*(ys)**(i+1)/(i+1) * (taylor[name][i-j]*binom(n+3, j)) 
    
    return dic


def IntegrandApprx(xs, xi, l, order=3, n=0):
    ys = xs-1
    taylor = Taylor(xi, l)
    order = min(len(taylor["E"]), order)
    #print(taylor["E"])
    
    dic = {"E":0, "B":0, "G":0}
    for name in dic.keys():
        for i in range(order):
            for j in range(i):
                dic[name] = dic[name] + taylor[name][i-j]*binom(n+3, j) * (ys)**(i)
    #print(dic["E"])
    return dic

# %%
xis = np.arange(1, 5, 1)
xs = np.linspace(0.25, 1, 100)
for xi in xis:
    E1 = []
    E21 = []
    E22 = []
    E23 = []
    E24 = []
    for x in xs:
        E1.append(iE(x, xi, 1))
        E21.append(IntegrandApprx(x, xi, 1, order=1)["E"])
        E22.append(IntegrandApprx(x, xi, 1, order=2)["E"])
        E23.append(IntegrandApprx(x, xi, 1, order=3)["E"])
    E1 = np.array(E1)
    E21 = np.array(E21)
    E22 = np.array(E22)
    E23 = np.array(E23)
    plt.plot(xs, E1, "k")
    plt.plot(xs, E21, "r")
    plt.plot(xs, E22, "b")
    plt.plot(xs, E23, "g")
    plt.plot(xs, E23, "y")
    plt.yscale("log")
    plt.show()

# %%
xis = np.arange(1, 5, 0.1)
xss = np.array([0.25, 0.5, 0.75, 0.9])

for xs in xss:
    q1 = []
    q21 = []
    q22 = []
    q23 = []
    q24 = []
    for xi in xis:
        q1.append(quad(iE, xs, 1., args=(xi,1,))[0] + quad(iE, xs, 1., args=(xi,-1,))[0])
        q21.append(IntApprx(xs, xi, 1, order=1)["E"] + IntApprx(xs, xi, -1, order=1)["E"])
        q22.append(IntApprx(xs, xi, 1, order=2)["E"] + IntApprx(xs, xi, -1, order=2)["E"])
        q23.append(IntApprx(xs, xi, 1, order=3)["E"] + IntApprx(xs, xi, -1, order=3)["E"])
    q1 = np.array(q1)
    q21 = np.array(q21)
    q22 = np.array(q22)
    q23 = np.array(q23)
    plt.plot(xis, q21/q1, "r.")
    plt.plot(xis, q22/q1, "b.")
    plt.plot(xis, q23/q1, "g.")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 12
#      10 for xi in xis:
#      11     q1.append(quad(iE, xs, 1., args=(xi,1,))[0] + quad(iE, xs, 1., args=(xi,-1,))[0])
# ---> 12     q21.append(IntApprx(xs, xi, 1, order=1)["E"] + IntApprx(xs, xi, -1, order=1)["E"])
#      13     q22.append(IntApprx(xs, xi, 1, order=2)["E"] + IntApprx(xs, xi, -1, order=2)["E"])
#      14     q23.append(IntApprx(xs, xi, 1, order=3)["E"] + IntApprx(xs, xi, -1, order=3)["E"])
#
# Cell In[22], line 30, in IntApprx(xs, xi, l, order, n)
#      28 def IntApprx(xs, xi, l, order=3, n=0):
#      29     ys = 1-xs
# ---> 30     taylor = Taylor(xi, l)
#      31     order = min(len(taylor["E"]), order)
#      33     dic = {"E":0, "B":0, "G":0}
#
# Cell In[22], line 5, in Taylor(xi, pol)
#       4 def Taylor(xi, pol):
# ----> 5     E = Ef(1, xi, pol)
#       6     G = Gf(1, xi, pol)
#       7     B = Bf(1, xi, pol)
#
# Cell In[21], line 2, in <lambda>(x, xi, l)
#       1 Ef = lambda x, xi, l: np.exp(l*np.pi*xi) * abs((2j*abs(xi) - 1j*xi)*whitw(-1j*xi*l, 1/2, -4j*abs(xi)*x)
# ----> 2                                                + complex(whitw(1-1j*xi*l, 1/2, -4j*abs(xi)*x)))**2/(2*abs(xi))**2
#       3 Bf = lambda x, xi, l: np.exp(l*np.pi*xi) * abs( whitw(-1j*xi*l, 1/2, -4j*abs(xi)*x) )**2
#       4 Gf = lambda x, xi, l: np.exp(l*np.pi*xi) * abs( whitw(1-1j*xi*l, 1/2, -4j*abs(xi)*x)*whitw(-1j*xi*l, 1/2, -4j*abs(xi)*x).conjugate()
#       5                                               )**2/(2*abs(xi))
#
# File ~/.conda/envs/ptarcade/lib/python3.10/site-packages/mpmath/ctx_mp_python.py:1023, in PythonMPContext._wrap_specfun.<locals>.f_wrapped(ctx, *args, **kwargs)
#    1021 try:
#    1022     ctx.prec += 10
# -> 1023     retval = f(ctx, *args, **kwargs)
#    1024 finally:
#    1025     ctx.prec = prec
#
# File ~/.conda/envs/ptarcade/lib/python3.10/site-packages/mpmath/functions/bessel.py:209, in whitw(ctx, k, m, z, **kwargs)
#     207 x = ctx.fmul(-0.5, z, exact=True)
#     208 y = 0.5+m
# --> 209 return ctx.exp(x) * z**y * ctx.hyperu(y-k, 1+2*m, z, **kwargs)
#
# File ~/.conda/envs/ptarcade/lib/python3.10/site-packages/mpmath/functions/bessel.py:238, in hyperu(ctx, a, b, z, **kwargs)
#     236     T2 = ([-ctx.pi,w,z],[1,-1,1-b],[],[a,2-b],[a-b+1],[2-b],z)
#     237     return T1, T2
# --> 238 return ctx.hypercomb(h, [a,b], **kwargs)
#
# File ~/.conda/envs/ptarcade/lib/python3.10/site-packages/mpmath/functions/hypergeometric.py:127, in hypercomb(ctx, function, params, discard_known_zeros, **kwargs)
#     120     print("    z", ctx.nstr(z))
#     121 #v = ctx.hyper(a_s, b_s, z, **kwargs)
#     122 #for a in alpha_s: v *= ctx.gamma(a)
#     123 #for b in beta_s: v *= ctx.rgamma(b)
#     124 #for w, c in zip(w_s, c_s): v *= ctx.power(w, c)
#     125 v = ctx.fprod([ctx.hyper(a_s, b_s, z, **kwargs)] + \
#     126     [ctx.gamma(a) for a in alpha_s] + \
# --> 127     [ctx.rgamma(b) for b in beta_s] + \
#     128     [ctx.power(w,c) for (w,c) in zip(w_s,c_s)])
#     129 if verbose:
#     130     print("    Value:", v)
#
# File ~/.conda/envs/ptarcade/lib/python3.10/site-packages/mpmath/functions/hypergeometric.py:127, in <listcomp>(.0)
#     120     print("    z", ctx.nstr(z))
#     121 #v = ctx.hyper(a_s, b_s, z, **kwargs)
#     122 #for a in alpha_s: v *= ctx.gamma(a)
#     123 #for b in beta_s: v *= ctx.rgamma(b)
#     124 #for w, c in zip(w_s, c_s): v *= ctx.power(w, c)
#     125 v = ctx.fprod([ctx.hyper(a_s, b_s, z, **kwargs)] + \
#     126     [ctx.gamma(a) for a in alpha_s] + \
# --> 127     [ctx.rgamma(b) for b in beta_s] + \
#     128     [ctx.power(w,c) for (w,c) in zip(w_s,c_s)])
#     129 if verbose:
#     130     print("    Value:", v)
#
# File ~/.conda/envs/ptarcade/lib/python3.10/site-packages/mpmath/ctx_mp_python.py:1007, in PythonMPContext._wrap_libmp_function.<locals>.f(x, **kwargs)
#    1005         return ctx.make_mpc(mpc_f((x._mpf_, fzero), prec, rounding))
#    1006 elif hasattr(x, '_mpc_'):
# -> 1007     return ctx.make_mpc(mpc_f(x._mpc_, prec, rounding))
#    1008 raise NotImplementedError("%s of a %s" % (name, type(x)))
#
# File ~/.conda/envs/ptarcade/lib/python3.10/site-packages/mpmath/libmp/gammazeta.py:2145, in mpc_rgamma(x, prec, rnd)
#    2144 def mpc_rgamma(x, prec, rnd='d'):
# -> 2145     return mpc_gamma(x, prec, rnd, 2)
#
# File ~/.conda/envs/ptarcade/lib/python3.10/site-packages/mpmath/libmp/gammazeta.py:2044, in mpc_gamma(z, prec, rnd, type)
#    2042 rim = MPZ_ZERO
#    2043 for k in xrange(d):
# -> 2044     rre, rim = ((afix*rre-bfix*rim)>>wp), ((afix*rim + bfix*rre)>>wp)
#    2045     afix += one
#    2046 r = from_man_exp(rre, -wp), from_man_exp(rim, -wp)
#
# KeyboardInterrupt:

# %%
alpha = 0.
Mpl = 1.
beta = 25.
M = 6e-6*Mpl
phi0 = 15.55*Mpl
dphidt0 = -np.sqrt(2/3)*M*Mpl
ini = {"phi":phi0, "dphi":dphidt0, "delta":1.0, "rhoChi":0.0}
SE = 0.0
ntr = 55
#G = GEF(alpha, beta, Mpl, ini, M, ntr, SE, AltDamp=0, approx=True)
#F = GEF(alpha, beta, Mpl, ini, M, ntr, SE, AltDamp=1, approx=True)
H = GEF(alpha, beta, Mpl, ini, M, ntr, SE, AltDamp=2, approx=True)
omega=H.H0

file = "Out/GEF_Beta25.0_SE-1.0_KDep_0it.dat"
H.LoadData(file)
H.Unitless()
NR = H.vals["N"]
xiR = H.vals["xi"]
khR = H.vals["kh"]
kSR = H.vals["kS"]

xsR = kSR/khR
# Out:
# Already Unitless

# %%
N = np.linspace(10, 50, 40)
xs = CubicSpline(NR, xsR)(N)
xi = CubicSpline(NR, xiR)(N)
q1 = []
q21 = []
q22 = []
q23 = []
q24 = []
for k in range(N.size):
    q1.append(quad(iE, xs[k], 1., args=(xi[k],1,))[0] + quad(iE, xs[k], 1., args=(xi[k],-1,))[0])
    q21.append(IEapprx(xs[k], xi[k], 1, order=1) + IEapprx(xs[k], xi[k], -1, order=1))
    q22.append(IEapprx(xs[k], xi[k], 1, order=2) + IEapprx(xs[k], xi[k], -1, order=2))
    q23.append(IEapprx(xs[k], xi[k], 1, order=3) + IEapprx(xs[k], xi[k], -1, order=3))
    q24.append(IEapprx(xs[k], xi[k], 1, order=4) + IEapprx(xs[k], xi[k], -1, order=4))
q1 = np.array(q1)
q21 = np.array(q21)
q22 = np.array(q22)
q23 = np.array(q23)
q24 = np.array(q24)
plt.plot(N, q21/q1, "r.")
plt.plot(N, q22/q1, "b.")
plt.plot(N, q23/q1, "g.")
plt.plot(N, q24/q1, "y.")
plt.show()

# %%
Q = lambda x, xi: np.exp(np.pi*xi/2) * complex(whitw(-1j*xi, 1/2, -4j*abs(xi)*x))
Qapprox = lambda x, xi: x**(1/4) * np.exp( xi*(np.pi-4.*x**(1/2) ))
Qapprox2 = lambda x, xi: 2*(x*xi/np.pi)**(1/2) * np.exp( xi*np.pi) * besselk(1, 4*xi*x**(1/2) )

# %%
xi = 3
x = np.linspace(0.25, 1.)
Qarr = abs(np.array([complex(Q(y, xi)) for y in x]))
Qarr2 = Qapprox(x, xi)
Qarr3 = Qapprox(x, xi)

# %%
plt.plot(x, Qarr)
plt.plot(x, Qarr2)
plt.plot(x, Qarr3)

# %%
plt.plot(x, Qarr2/Qarr)
plt.yscale("log")
#plt.plot(x, Qarr2/Qarr3)

# %%
int1 = lambda x, xi: x**4*abs(Q(x, xi)**2)
int2 = lambda x, xi: x**4*Qapprox(x, xi)**2

# %%
quad1 = lambda xi: quad(int1, 0.25, 1., args=(xi,))
quad2 = lambda xi: quad(int2, 0.25, 1., args=(xi,))

# %%
xis = np.arange(1, 5, 0.1)

# %%
q1 = []
q2 = []
for xi in xis:
    q1.append(quad1(xi)[0])
    q2.append(quad2(xi)[0])

# %%
plt.plot(xis, np.array(q1), "r.")
plt.plot(xis, np.array(q2), "b.")

# %%
def Eapprx2(xs, xi, l):
    x = -0.325/xi + 0.97
    #print(x)
    y = (x - xs)
    E = Ef(x, xi, l)
    G = Gf(x, xi, l)
    B = Bf(x, xi, l)
    t0 = E*x**3
    kappa = l*np.sign(xi)
    xi = abs(xi)
    Eprime = (1-kappa)/(x*xi)*G
    E2prime = (-1 + kappa)*(x*E + 2*xi*G
          + (-x+kappa)*B)/(2*x**2*xi**2)
    t1 = 0#3*x**2*E + x**3*Eprime
    t2 = (6*x*E + 6*x**2*Eprime + x**3*E2prime)/2
    return t0 + t1*y + t2*y**2

# %%
xis = np.arange(1, 5, 1)
xs = np.linspace(0.25, 1, 100)
for xi in xis:
    E1 = []
    E21 = []
    for x in xs:
        E1.append(iE(x, xi, 1))
        E21.append(Eapprx2(x, xi, 1))
    E1 = np.array(E1)
    E21 = np.array(E21)
    plt.plot(xs, E1, "k")
    plt.plot(xs, E21, "r")
    #plt.yscale("log")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 7
#       5 E21 = []
#       6 for x in xs:
# ----> 7     E1.append(iE(x, xi, 1))
#       8     E21.append(Eapprx2(x, xi, 1))
#       9 E1 = np.array(E1)
#
# Cell In[15], line 1, in <lambda>(x, xi, l)
# ----> 1 iE = lambda x, xi, l: x**3*Ef(x, xi, l)
#       3 def iEapprx(xs, xi, l, order=3):
#       4     ys = xs-1
#
# Cell In[4], line 1, in <lambda>(x, xi, l)
# ----> 1 Ef = lambda x, xi, l: abs(P(x, xi, l))**2
#       2 Bf = lambda x, xi, l: abs(Q(x, xi, l))**2
#       3 Gf = lambda x, xi, l: (P(x, xi, l)*Q(x, xi, l).conjugate()).real
#
# Cell In[3], line 3, in <lambda>(x, xi, l)
#       1 Q = lambda x, xi, l: np.exp(l*np.pi*xi/2) * complex(whitw(-1j*xi*l, 1/2, -4j*abs(xi)*x))
#       2 P = lambda x, xi, l: np.exp(l*np.pi*xi/2) * (complex(whitw(-1j*xi*l, 1/2, -4j*abs(xi)*x))*1j*(1-l/2*np.sign(xi))
# ----> 3                                              + complex(whitw(1-1j*xi*l, 1/2, -4j*abs(xi)*x))/(2*abs(xi)*x))
#
# File ~/.conda/envs/ptarcade/lib/python3.10/site-packages/mpmath/ctx_mp_python.py:1023, in PythonMPContext._wrap_specfun.<locals>.f_wrapped(ctx, *args, **kwargs)
#    1021 try:
#    1022     ctx.prec += 10
# -> 1023     retval = f(ctx, *args, **kwargs)
#    1024 finally:
#    1025     ctx.prec = prec
#
# File ~/.conda/envs/ptarcade/lib/python3.10/site-packages/mpmath/functions/bessel.py:209, in whitw(ctx, k, m, z, **kwargs)
#     207 x = ctx.fmul(-0.5, z, exact=True)
#     208 y = 0.5+m
# --> 209 return ctx.exp(x) * z**y * ctx.hyperu(y-k, 1+2*m, z, **kwargs)
#
# File ~/.conda/envs/ptarcade/lib/python3.10/site-packages/mpmath/functions/bessel.py:238, in hyperu(ctx, a, b, z, **kwargs)
#     236     T2 = ([-ctx.pi,w,z],[1,-1,1-b],[],[a,2-b],[a-b+1],[2-b],z)
#     237     return T1, T2
# --> 238 return ctx.hypercomb(h, [a,b], **kwargs)
#
# File ~/.conda/envs/ptarcade/lib/python3.10/site-packages/mpmath/functions/hypergeometric.py:125, in hypercomb(ctx, function, params, discard_known_zeros, **kwargs)
#     120     print("    z", ctx.nstr(z))
#     121 #v = ctx.hyper(a_s, b_s, z, **kwargs)
#     122 #for a in alpha_s: v *= ctx.gamma(a)
#     123 #for b in beta_s: v *= ctx.rgamma(b)
#     124 #for w, c in zip(w_s, c_s): v *= ctx.power(w, c)
# --> 125 v = ctx.fprod([ctx.hyper(a_s, b_s, z, **kwargs)] + \
#     126     [ctx.gamma(a) for a in alpha_s] + \
#     127     [ctx.rgamma(b) for b in beta_s] + \
#     128     [ctx.power(w,c) for (w,c) in zip(w_s,c_s)])
#     129 if verbose:
#     130     print("    Value:", v)
#
# File ~/.conda/envs/ptarcade/lib/python3.10/site-packages/mpmath/functions/hypergeometric.py:222, in hyper(ctx, a_s, b_s, z, **kwargs)
#     220     elif q == 0: return ctx.exp(z)
#     221 elif p == 1:
# --> 222     if   q == 1: return ctx._hyp1f1(a_s, b_s, z, **kwargs)
#     223     elif q == 2: return ctx._hyp1f2(a_s, b_s, z, **kwargs)
#     224     elif q == 0: return ctx._hyp1f0(a_s[0][0], z)
#
# File ~/.conda/envs/ptarcade/lib/python3.10/site-packages/mpmath/functions/hypergeometric.py:342, in _hyp1f1(ctx, a_s, b_s, z, **kwargs)
#     340     finally:
#     341         ctx.prec -= magz
# --> 342 v = ctx.hypsum(1, 1, (atype, btype), [a, b], z, **kwargs)
#     343 return v
#
# File ~/.conda/envs/ptarcade/lib/python3.10/site-packages/mpmath/ctx_mp.py:714, in MPContext.hypsum(ctx, p, q, flags, coeffs, z, accurate_small, **kwargs)
#     712 else:
#     713     mag_dict = {}
# --> 714 zv, have_complex, magnitude = summator(coeffs, v, prec, wp, \
#     715     epsshift, mag_dict, **kwargs)
#     716 cancel = -magnitude
#     717 jumps_resolved = True
#
# File <string>:61, in hypsum_1_1_C_R_C(coeffs, z, prec, wp, epsshift, magnitude_check, **kwargs)
#
# KeyboardInterrupt:

# %%
xis = np.arange(1, 5, 0.1)
xs = np.linspace(0.25, 1, 1000)
m = []
for xi in xis:
    iEs = 1e100
    xmin = 0.
    for x in xs:
        etmp = iE(x, xi, 1.)
        if etmp < iEs:
            iEs = etmp
            xmin = x
    m.append(xmin)
plt.plot(xis, m, "r.")

# %%
f = lambda x, a, b: -a/x+b

# %%
val = curve_fit(f, xis, np.array(m), p0=[3.8/4-0.7, 3.8/4])[0]

# %%
print(val)
# Out:
# [0.32581465 0.97002392]

# %%
plt.plot(xis, m, "r.")
plt.plot(xis, f(xis, 0.325, 0.97))
#plt.xscale("log")
